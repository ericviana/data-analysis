# %% [markdown]
# # Aula05 - Visualização de Dados em Python
#
# **Conteúdo**
# - Gráficos - Tipos de Visualizações
# - Pandas - Visualização de dados
# - Seaborn - Dados Estatísticos
# - Bokeh - Mapas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
#configuração para mostrar gráficos sem chamar a função show()
# %matplotlib inline
#configuração do notebook para acesso local aos datasets
path = '/content/drive/MyDrive/2022_2_extensao_adp/datasets/'

# %% [markdown]
# ### 1. Visualizaçao com o Pandas
#
# Pandas possui um biblioteca para visualização de dados integrada em sua API.

# %%
# Importacao das bibliotecas e configuracoes gerais
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set seaborn aesthetic parameters to defaults
sns.set()
sns.set_context("notebook")
sns.set(rc={'figure.figsize':(10, 7)})

# %% [markdown]
# Função para geração do gráfico
#
# > *.plot(data, x, y)*

# %% [markdown]
# **Exemplo 01**: Gráfico de todos os dados do Dataframe
#
#
#
# INDICADOR | AGO/2021 | SET/2021 | OUT/2021 | NOV/2021 | DEZ/2021 | JAN/2022 | FEV/2022 | MAR/2022 | ABR/2022 | MAI/2022 | JUN/2022 | JUL/2022
# ---|---|---|---|---|---|---|---|---|---|---|---|---|
# IPCA | 0,87% | 1,16% | 1,25% | 0,95% | 0,73% | 0,54% | 1,01% | 1,62% | 1,06% | 0,47% | 0,67% | -0,68% |
# IGPM | 0,66% | -0,64% | 0,64% | 0,02% | 0,87% | 1,82% | 1,83% | 1,74% | 1,41% | 0,52% | 0,59% | 0,21% |
# CDI | 0,43% | 0,44% | 0,49% | 0,59% | 0,77% | 0,73% | 0,76% | 0,93% | 0,83% | 1,03% | 1,02% | 1,03% |
# IBOV | -2,48% | -6,57% | -6,74% | -1,5% | 2,85% | 6,98% | 0,89% | 6,06% | -10,10% | 3,22% | -11,50% | 4,69%

# %%
referencias = ['ago', 'set', 'out', 'nov', 'dez', 'jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul']
cdi = [0.43, 0.44, 0.49, 0.59, 0.77, 0.73, 0.76, 0.93, 0.83, 1.03, 1.02, 1.03]
ipca = [0.87, 1.16, 1.25, 0.95, 0.73, 0.54, 1.01, 1.62, 1.06, 0.47, 0.67, -0.68]
igpm = [0.66, -0.64, 0.64, 0.02, 0.87, 1.82, 1.83, 1.74, 1.41, 0.52, 0.59, 0.21]
ibov = [ -2.48, -6.57, -6.74, -1.5, 2.85, 6.98, 0.89, 6.06, -10.10, 3.22, -11.50, 4.69]

df_indicadores = pd.DataFrame(data={'IPCA': ipca, 'CDI': cdi, 'IGPM': igpm, 
                                    'IBOV' : ibov}, index=referencias)
df_indicadores.plot()

# %%
df_indicadores
# Out:
#      IPCA   CDI  IGPM   IBOV
# ago  0.87  0.43  0.66  -2.48
# set  1.16  0.44 -0.64  -6.57
# out  1.25  0.49  0.64  -6.74
# nov  0.95  0.59  0.02  -1.50
# dez  0.73  0.77  0.87   2.85
# jan  0.54  0.73  1.82   6.98
# fev  1.01  0.76  1.83   0.89
# mar  1.62  0.93  1.74   6.06
# abr  1.06  0.83  1.41 -10.10
# mai  0.47  1.03  0.52   3.22
# jun  0.67  1.02  0.59 -11.50
# jul -0.68  1.03  0.21   4.69

# %% [markdown]
# **Exemplo 02**: Visualização de selação de dados

# %%
# seleção dos indicadores IPCA e IGPM para compor a visualização
df_indicadores[['IPCA', 'IGPM']].plot()

# %% [markdown]
# #### **Exercício 1.01**
#
# Apresentar o gráfico dos indicadores IBOV e CDI

# %%
# Implmentação Ex01
#
df_indicadores[['IBOV', 'CDI']].plot()

# %% [markdown]
# #### Figuras e subplotagens

# %%
fig=plt.figure(figsize=(15, 10))
ax1=fig.add_subplot(221)
ax2=fig.add_subplot(222)
ax3=fig.add_subplot(223)
ax4=fig.add_subplot(224)
ax1.plot(df_indicadores['IPCA'], 'go-', label='IPCA', linewidth=2)
ax1.legend(loc='best')
ax2.plot(df_indicadores['IGPM'], 'rs',  label='IGPM')
ax2.legend(loc='best')
ax3.plot(df_indicadores['CDI'], 'k--', label='CDI')
ax3.legend(loc='best')
ax4.plot(df_indicadores['IBOV'], 'm.', label='IBOV')
ax4.legend(loc='best')
plt.show()

# %%
fig=plt.figure(figsize=(15, 5))
ax1=fig.add_subplot(121)
ax2=fig.add_subplot(122)
ax1.plot(df_indicadores['IPCA'], 'go-', label='IPCA', linewidth=2)
ax1.plot(df_indicadores['IGPM'], 'rs-',  label='IGPM')
ax1.legend(loc='best')

ax2.plot(df_indicadores['CDI'], 'k--', label='CDI')
ax2.legend(loc='best')
ax2.plot(df_indicadores['IBOV'], 'm.-', label='IBOV')
ax2.legend(loc='best')
plt.show()

# %% [markdown]
# #### **Exercício 1.02**
#
# Apresentar os 4 gráficos acima em 4 linhas e 1 coluna

# %%
# solução
# 4 SUBPLOTS 4x1x1
fig=plt.figure(figsize=(15, 20))
ax1=fig.add_subplot(411)
ax2=fig.add_subplot(412)
ax3=fig.add_subplot(413)
ax4=fig.add_subplot(414)
ax1.plot(df_indicadores['IPCA'], 'go-', label='IPCA', linewidth=2)
ax1.legend(loc='best')
ax2.plot(df_indicadores['IGPM'], 'rs',  label='IGPM')
ax2.legend(loc='best')
ax3.plot(df_indicadores['CDI'], 'k--', label='CDI')
ax3.legend(loc='best')
ax4.plot(df_indicadores['IBOV'], 'm.', label='IBOV')
ax4.legend(loc='best')
# jogar a legenda fora do gráfico
ax1.legend(loc='upper right', bbox_to_anchor=(1.1, 0.9), shadow=True, ncol=2)
plt.show()

# %% [markdown]
# ### 2. Tipos de Visualizações

# %% [markdown]
# #### Linha
#
# Indicado para apresentação de dados contínuos

# %% [markdown]
# **Exemplo 2.01** Visualização dos indicadores econômicos ao longo do tempo

# %%
# seleção dos indicadores IPCA e IGPM para compor a visualização
df_indicadores[['IPCA', 'IGPM']].plot()

# %% [markdown]
# #### Barras
#
# Indicado para a comparação de magnitudes entre diferentes categorias
#
# > *.bar(x, y)*

# %% [markdown]
# **Exemplo 2.02**  - Visualização da série de indicadores em gráfico de barras.

# %%
# gráfico de barras com inclusão do título
df_indicadores[['IPCA', 'IGPM']].plot.bar()

# %% [markdown]
# #### Pizza
#
# Utilizado para indicar proporções relativas de categorias
#
# > *.pie(y)*

# %% [markdown]
# **Exemplo 2.03** Visualização da proporção dos procedimentos de compra em licitações da BEC no ano

# %%
# carregamento do dataset da BEC e geração de informações de quantidade negociada
df_bec = pd.read_excel(path+'03-DS_BEC.xlsx')
df_bec = df_bec[['Cód Desc Órgão', 'Mês Ano Encerramento', 'Cod Desc Fornecedor', 
                 'Descrição Procedimento Compra', 'Cod Desc Item', 
                 'Quantidade de Item','Valor Unitário Negociado', 
                 'Valor Total Negociado em R$']]
df_bec['Quantidade Negociada'] = df_bec['Valor Total Negociado em R$'] / df_bec[
    'Valor Unitário Negociado']  
df_bec.head(4)
# Out:
#                    Cód Desc Órgão Mês Ano Encerramento  \
# 0  01000 - ASSEMBLEIA LEGISLATIVA           2019-09-01
# 1  01000 - ASSEMBLEIA LEGISLATIVA           2019-09-01
# 2  01000 - ASSEMBLEIA LEGISLATIVA           2019-09-01
# 3  01000 - ASSEMBLEIA LEGISLATIVA           2019-09-01
#
#                                  Cod Desc Fornecedor  \
# 0   28363983000140 - OFICIAL WEB COMERCIAL LTDA - ME
# 1        12517378000146 - A. C. DOS SANTOS MÓVEIS ME
# 2  17365274000187 - CBF COMÉRCIO DE CONFECÇÕES BA...
# 3  23183671000130 - GALEQ COMÉRCIO INTERNACIONAL ...
#
#   Descrição Procedimento Compra  \
# 0         DISPENSA DE LICITAÇÃO
# 1         DISPENSA DE LICITAÇÃO
# 2         DISPENSA DE LICITAÇÃO
# 3         DISPENSA DE LICITAÇÃO
#
#                                        Cod Desc Item  Quantidade de Item  \
# 0  4843274 - FILME PROTETIVO, DE POLIESTER, 1,00X...                   1
# 1  4863801 - ESTANTE DESMONTAVEL DE ACO,ABERTA,06...                   1
# 2  4628020 - BANDEIRA,MUNICIPIO DE SAO PAULO, MED...                   1
# 3                         5133017 - NO-BREAK, 600 VA                   1
#
#    Valor Unitário Negociado  Valor Total Negociado em R$  Quantidade Negociada
# 0                     168.3                        673.2                   4.0
# 1                     235.0                       1880.0                   8.0
# 2                     170.0                        340.0                   2.0
# 3                      27.6                       1104.0                  40.0

# %%
# quantificação das ocorrências de procedimento de compra para visualização
df_bec['Descrição Procedimento Compra'].value_counts().plot.pie(
    x='Descrição Procedimento Compra')

# %% [markdown]
# #### Histograma
#
# Representação gráfica da distribuição de frequência de dados tabulados e divididos em classes
#
# > *.hist(bins)*

# %% [markdown]
# **Exemplo 2.04** - Visualização da frequência de valores unitários de feijão adquiridos pelo BEC

# %%
# histograma com a frequência de valores negociados do item Feijão Carioca
df_bec.loc[df_bec['Cod Desc Item'] == '120456 - FEIJAO CARIOCA, GRUPO 1, TIPO 1', 
           'Valor Unitário Negociado'].plot.hist(bins=20)

# %% [markdown]
# #### Função Densidade de Probabilidade
#
# Indicado para visualizar a probabilidade relativa de uma variável aleatória tomar um valor.
#
# > *.kde()*

# %% [markdown]
# **Exemplo 2.05** - Visualização da probablidade estimada de ocorrência do valor unitário do feijão em aquisições na BEC

# %%
# função de densidade estimada
df_bec.loc[df_bec['Cod Desc Item'] == 
           '120456 - FEIJAO CARIOCA, GRUPO 1, TIPO 1', 
           'Valor Unitário Negociado'].plot.kde()

# %% [markdown]
# #### Boxplot
#
# Utilizado para descrever grupos de dados numéricos distribuídos nos respectivos quartis.
#
# > *.box(data, column)*

# %% [markdown]
# **Exemplo 2.06** - Visualização da dispersão valores de aquisição de feijão distribuídas nos percentis com a estimativa de possíveis outliers

# %%
# estatísticas gerais
df_bec.loc[df_bec['Cod Desc Item'] == 
           '120456 - FEIJAO CARIOCA, GRUPO 1, TIPO 1', 
           ['Valor Unitário Negociado']].describe()
# Out:
#        Valor Unitário Negociado
# count                473.000000
# mean                   3.111049
# std                    1.327834
# min                    1.850000
# 25%                    2.350000
# 50%                    2.690000
# 75%                    3.450000
# max                   11.210000

# %%
# visualização dos dos grupos de valores negociados do feijão com a seleção 
# de possíveis outliers
df_bec.loc[df_bec['Cod Desc Item'] == 
           '120456 - FEIJAO CARIOCA, GRUPO 1, TIPO 1', 
           'Valor Unitário Negociado'].plot.box()

# %% [markdown]
# **Dados para os exercícios:**

# %%
df_bec.head(1)
# Out:
#                    Cód Desc Órgão Mês Ano Encerramento  \
# 0  01000 - ASSEMBLEIA LEGISLATIVA           2019-09-01
#
#                                 Cod Desc Fornecedor  \
# 0  28363983000140 - OFICIAL WEB COMERCIAL LTDA - ME
#
#   Descrição Procedimento Compra  \
# 0         DISPENSA DE LICITAÇÃO
#
#                                        Cod Desc Item  Quantidade de Item  \
# 0  4843274 - FILME PROTETIVO, DE POLIESTER, 1,00X...                   1
#
#    Valor Unitário Negociado  Valor Total Negociado em R$  Quantidade Negociada
# 0                     168.3                        673.2                   4.0

# %% [markdown]
# #### Exercício 2.01
#
# Apresentar o 'Valor Total Negociado em R$' pela '20000 - SECRETARIA DA FAZENDA E PLANEJAMENTO' ao longo dos meses

# %%
# Implementação Ex02.1
#
data = df_bec.loc[df_bec["Cód Desc Órgão"]=="20000 - SECRETARIA DA FAZENDA E PLANEJAMENTO"]\
.groupby('Mês Ano Encerramento')[['Valor Total Negociado em R$']].sum()
data.plot.bar()

# %% [markdown]
# #### Exercício 2.02
#
# Apresentar a proporção do 'Valor Total Negociado em R$' para cada um dos tipos de procedimentos de compra

# %%
# Implementação Ex02.2
#
#
data = df_bec.groupby('Descrição Procedimento Compra')[['Valor Total Negociado em R$']].sum()
data.plot.pie(y='Valor Total Negociado em R$')

# %%
# Implementação Alternativa do Ex02.2
#
#
data = df_bec.groupby('Descrição Procedimento Compra')[['Valor Total Negociado em R$']].sum()
data.plot.bar()

# %% [markdown]
# ### Dicas para fazer bons gráficos
#
# Para saber mais sobre o tipo de gráfico adequado para cada coisa que se quer mostrar, dê uma olhada em [The Data Visualization Catalogue](https://datavizcatalogue.com)
#
# Uma versão mais resumida por [Andrew Abela](https://extremepresentation.typepad.com/blog/2006/09/choosing_a_good.html)
#
# #### Mais dicas
#
# - [Como fazer bons gráficos de pizza](https://www.darkhorseanalytics.com/portfolio/2016/1/7/data-looks-better-naked-pie-charts)
# - [Como fazer bons gráficos de barras](https://www.darkhorseanalytics.com/portfolio/data-looks-better-naked-bar-charts)
# - [Como formatar uma tabela de dados](https://www.darkhorseanalytics.com/portfolio/2016/1/7/data-looks-better-naked-clear-off-the-table)
#
# **Lembre-se sempre: menos é mais!**

# %% [markdown]
# ### 3. Customização dos Gráficos

# %% [markdown]
# Lista das principais customizações permitidas pelo Pandas:
#
#
# Argumento | Descrição
# ----------|-----------
# label | Rótulo para legenda do gráfico
# kind | Tipo: bar, barh, density, hist, kde, line, pie
# use_index | Usar índice como rótulo
# rot| Rotação dos rótulos (0-360)
# xticks | Rótulos do eixo x
# yticks | Rótulos do eixo y
# sort_columns | Ordenar colunas
# xlim | Limite do eixo x
# ylim | Limite do eixo y
# grid | Exibir gride
# subplots | Plota cada coluna em um gráfico independente
# sharex | Compartilha o eixo x
# sharey | Compartilha o eixo y
# figsize| Tamanho da figura (tupla)
# title | Título do gráfico
# legend | Exibir legenda

# %%
df_bec.head(2)
# Out:
#                    Cód Desc Órgão Mês Ano Encerramento  \
# 0  01000 - ASSEMBLEIA LEGISLATIVA           2019-09-01
# 1  01000 - ASSEMBLEIA LEGISLATIVA           2019-09-01
#
#                                 Cod Desc Fornecedor  \
# 0  28363983000140 - OFICIAL WEB COMERCIAL LTDA - ME
# 1       12517378000146 - A. C. DOS SANTOS MÓVEIS ME
#
#   Descrição Procedimento Compra  \
# 0         DISPENSA DE LICITAÇÃO
# 1         DISPENSA DE LICITAÇÃO
#
#                                        Cod Desc Item  Quantidade de Item  \
# 0  4843274 - FILME PROTETIVO, DE POLIESTER, 1,00X...                   1
# 1  4863801 - ESTANTE DESMONTAVEL DE ACO,ABERTA,06...                   1
#
#    Valor Unitário Negociado  Valor Total Negociado em R$  Quantidade Negociada
# 0                     168.3                        673.2                   4.0
# 1                     235.0                       1880.0                   8.0

# %% [markdown]
# **Exemplo 3.01** Total Negociado por tipo de procedimento de compra

# %%
data = (
    df_bec[df_bec['Cód Desc Órgão'] == '20000 - SECRETARIA DA FAZENDA E PLANEJAMENTO']
    .groupby('Descrição Procedimento Compra')
    .agg({'Valor Total Negociado em R$' : 'sum'})
)

#grafico sem ajustes
data.plot.pie(y='Valor Total Negociado em R$')

# %% [markdown]
# ------

# %%
#versao ajustada
data.plot.pie(y='Valor Total Negociado em R$', label='', 
              title='Valor Total Negociado por Procedimento de Compra', legend=True,
              fontsize=15, figsize=(10,10))

# %% [markdown]
# #### Exercício 3.01
#
# Adicionar o título adequado para o gráfico resposta do exercício 2.01

# %%
# Implementação Ex3.01
#
data = df_bec.loc[df_bec["Cód Desc Órgão"]=="20000 - SECRETARIA DA FAZENDA E PLANEJAMENTO"]\
.groupby('Mês Ano Encerramento')[['Valor Total Negociado em R$']].sum()
data.plot.bar(title = "SECRETARIA DA FAZENDA E PLANEJAMENTO\nValor total mensal das licitações - Jan a Out/2019")

# %% [markdown]
# ### 4. Seaborn - Dados Estatísticos
#
# Seaborn é uma biblioteca python para visualização de dados baseada no Matplotlib com foco na geração de gráficos estatíscos.

# %% [markdown]
# #### Linha
#
# Por padrão agrega múltiplos valores de y em cada valor de x e apresenta uma estimativa da tendência central e intervalo de confiança.
#
# > *.lineplot(data, x, y, hue)*

# %% [markdown]
# **Exemplo 04.1** - Valores negociados do item feijão carioca ao longo do ano

# %%
orgaos = ['18000 - SECRETARIA DA SEGURANCA PUBLICA',
          '38000 - SECRETARIA ADMINISTRACAO PENITENCIARIA']
item = '120456 - FEIJAO CARIOCA, GRUPO 1, TIPO 1'
data = df_bec.loc[(df_bec['Cod Desc Item'] == item) & 
                  (df_bec['Cód Desc Órgão'].isin(orgaos)), ['Mês Ano Encerramento', 
                                                            'Valor Unitário Negociado',
                                                            'Cód Desc Órgão']]
sns.lineplot(x="Mês Ano Encerramento", y="Valor Unitário Negociado", hue='Cód Desc Órgão', palette=["m", "g"], data=data)

# %% [markdown]
# #### Distplot
#
# Combina as visualizações de histograma e função de densidade de probabilidade.
#
# > *.distplot(data)*

# %% [markdown]
# **Exemplo 04.02** - Frequencia e distribuição de probabilidade de valores na aquisição do feijão carioca

# %%
data = df_bec.loc[df_bec['Cod Desc Item'] == '120456 - FEIJAO CARIOCA, GRUPO 1, TIPO 1', 
                  ['Valor Unitário Negociado']]
sns.distplot(data, color='b')

# %% [markdown]
# #### Boxplot
#
# Faz o boxplot, como vimos anteriormente, mas com o seaborn. O default é imprimir na horizontal. Para imprimir na vertical faça y = data.
#
# > *.boxplot(data)*
#
# #### Violinplot
#
# Um boxplot que usa a distribuição de probabilidade para desenhar a caixinha em vez de fazer retangular. O default também é imprimir na horizontal. Para imprimir na vertical faça y = data.
#
# > *.violinplot(data)*

# %%
data = df_bec.loc[df_bec['Cod Desc Item'] == '120456 - FEIJAO CARIOCA, GRUPO 1, TIPO 1']

# %%
plt.figure(figsize=(15, 10))
ax=plt.subplot(121)
sns.violinplot(y='Valor Unitário Negociado', data=data, color='b')
plt.title('Violin Plot')
ax=plt.subplot(122)
sns.boxplot(y='Valor Unitário Negociado', data=data, color='b')
plt.title('Box Plot')
plt.show()

# %%
# cortando abaixo de 4.6 para remover um pouco dos outliers
data = data[data['Valor Unitário Negociado'] < 4.6]

# %%
plt.figure(figsize=(15, 10))
ax=plt.subplot(121)
# configura o range do eixo x
plt.ylim(1.3,5.0)
sns.violinplot(y='Valor Unitário Negociado', data=data, color='b')
plt.title('Violin Plot')
ax=plt.subplot(122)
plt.ylim(1.3,5.0)
sns.boxplot(y='Valor Unitário Negociado', data=data, color='b')
plt.title('Box Plot')
plt.show()

# %%
ax = sns.boxplot(x='Mês Ano Encerramento', y='Valor Unitário Negociado', data = data)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# Out:
# [Text(0, 0, '2019-06-01T00:00:00.000000000'),
#  Text(0, 0, '2019-08-01T00:00:00.000000000'),
#  Text(0, 0, '2019-04-01T00:00:00.000000000'),
#  Text(0, 0, '2019-05-01T00:00:00.000000000'),
#  Text(0, 0, '2019-09-01T00:00:00.000000000'),
#  Text(0, 0, '2019-07-01T00:00:00.000000000'),
#  Text(0, 0, '2019-03-01T00:00:00.000000000'),
#  Text(0, 0, '2019-10-01T00:00:00.000000000'),
#  Text(0, 0, '2019-01-01T00:00:00.000000000'),
#  Text(0, 0, '2019-02-01T00:00:00.000000000')]

# %% [markdown]
# #### Regressão
#
# Apresenta dados e a regressão linear estimada.
#
# > *.regplot(x, y, data)*

# %% [markdown]
# **Exemplo 04.03** - Valores negociados do item Papel Sulfite em função da quaintidade negociada

# %%
df_papel = df_bec[df_bec['Cod Desc Item'] == 
            '2903881 - PAPEL SULFITE DE PAPELARIA,FORMATO A4,(210X297)MM,75G,BRANCO']
data = df_papel[['Quantidade Negociada', 'Valor Unitário Negociado','Descrição Procedimento Compra']]
# mais este filtro abaixo para remover outliers que distorcem o gráfico
data = data[(data['Quantidade Negociada'] < 20000) & 
            (data['Valor Unitário Negociado'] < 120)]
sns.scatterplot(x='Quantidade Negociada', y='Valor Unitário Negociado', hue = 'Descrição Procedimento Compra',data=data)

# %%
ax = sns.regplot(x='Quantidade Negociada', y='Valor Unitário Negociado', data=data)

# %% [markdown]
# #### Jointplot
#
# Visualiza os dados combinando a regressão linear estimada com a função de distribuição de probabilidade.
#
# > *.jointplot(x, y, data, kind="reg")*

# %% [markdown]
# **Exemplo 04.04** Jointplot dos valores negociados do item Papel Sulfite em função da quaintidade negociada

# %%
g = sns.jointplot(x='Quantidade Negociada', y='Valor Unitário Negociado', data=data, 
                  kind="reg", color="m", height=7)

# %% [markdown]
# #### Heatmap
#
# Representação gráfica que utiliza um sistema de cores para representar diferentes valores.
#
# > *.heatmap(data)*

# %% [markdown]
# **Exemplo 4.05** - Visualização do nível de correlação entre diferentes ações da bolsa

# %%
df_acoes = pd.read_csv(path+'04-DS_ACOES.csv', sep=';', 
                       parse_dates=['Date'])
df_acoes.set_index('Date', inplace=True)
df_acoes.head(5)
# Out:
#              VALE3.SA  LREN3.SA  CMIG3.SA  OIBR4.SA   BBDC3.SA  ITSA4.SA  \
# Date
# 2018-01-02  41.720001       NaN      6.60      3.42  24.454500   10.0273
# 2018-01-03  41.470001       NaN      6.61      3.42  24.545500   10.1454
# 2018-01-04  41.639999       NaN      6.55      3.42  24.992399   10.3364
# 2018-01-05  42.290001       NaN      6.55      3.44  25.000000   10.3546
# 2018-01-08  43.230000       NaN      6.50      3.43  25.000000   10.3455
#
#             USIM5.SA  BRML3.SA   PETR3.SA   VIVT4.SA  ENBR3.SA   RADL3.SA
# Date
# 2018-01-02      9.60     12.40  17.330000  49.009998     14.20  90.449997
# 2018-01-03      9.92     12.36  17.549999  48.419998     13.56  88.209999
# 2018-01-04     10.48     12.51  17.700001  49.400002     13.58  88.889999
# 2018-01-05     10.03     12.55  17.840000  49.630001     13.46  90.449997
# 2018-01-08     10.14     12.50  18.120001  50.009998     13.68  89.300003

# %%
df_acoes.loc['2019'].corr()
# Out:
#           VALE3.SA  LREN3.SA  CMIG3.SA  OIBR4.SA  BBDC3.SA  ITSA4.SA  \
# VALE3.SA  1.000000 -0.300336  0.151562  0.350432  0.256152 -0.090566
# LREN3.SA -0.300336  1.000000 -0.522922 -0.417828 -0.061771  0.639815
# CMIG3.SA  0.151562 -0.522922  1.000000  0.555998  0.084792 -0.396482
# OIBR4.SA  0.350432 -0.417828  0.555998  1.000000  0.198708 -0.356686
# BBDC3.SA  0.256152 -0.061771  0.084792  0.198708  1.000000  0.618865
# ITSA4.SA -0.090566  0.639815 -0.396482 -0.356686  0.618865  1.000000
# USIM5.SA  0.467885 -0.380832  0.162047  0.409014  0.351139 -0.033982
# BRML3.SA -0.213964  0.771092 -0.243775 -0.342550  0.419210  0.819461
# PETR3.SA  0.313746  0.300725 -0.319401  0.100109  0.566406  0.394789
# VIVT4.SA -0.238705  0.895194 -0.199573 -0.288202  0.141919  0.584807
# ENBR3.SA -0.372928  0.098668  0.319140  0.137169  0.166774  0.186629
# RADL3.SA -0.259503  0.841225 -0.357341 -0.378352 -0.030529  0.468555
#
#           USIM5.SA  BRML3.SA  PETR3.SA  VIVT4.SA  ENBR3.SA  RADL3.SA
# VALE3.SA  0.467885 -0.213964  0.313746 -0.238705 -0.372928 -0.259503
# LREN3.SA -0.380832  0.771092  0.300725  0.895194  0.098668  0.841225
# CMIG3.SA  0.162047 -0.243775 -0.319401 -0.199573  0.319140 -0.357341
# OIBR4.SA  0.409014 -0.342550  0.100109 -0.288202  0.137169 -0.378352
# BBDC3.SA  0.351139  0.419210  0.566406  0.141919  0.166774 -0.030529
# ITSA4.SA -0.033982  0.819461  0.394789  0.584807  0.186629  0.468555
# USIM5.SA  1.000000 -0.321135  0.200875 -0.593290 -0.588696 -0.768013
# BRML3.SA -0.321135  1.000000  0.204983  0.785688  0.444905  0.689287
# PETR3.SA  0.200875  0.204983  1.000000  0.143275  0.028503  0.197816
# VIVT4.SA -0.593290  0.785688  0.143275  1.000000  0.655438  0.873321
# ENBR3.SA -0.588696  0.444905  0.028503  0.655438  1.000000  0.586344
# RADL3.SA -0.768013  0.689287  0.197816  0.873321  0.586344  1.000000

# %%
sns.heatmap(df_acoes.loc['2019'].corr())

# %% [markdown]
# #### Pairplot
#
# Plota as correlações entre variáveis na linha e na coluna, duas a duas. Na diagonal principal plota o histograma da linha ou coluna, pois os valores são os mesmos, em vez de apresentar uma correlação 1.
#
# > *.pairplot(data)*

# %%
sns.pairplot(df_acoes.loc['2019'].corr())

# %% [markdown]
# #### Exercício 4.01
#
# Apresentar os valores negociados do item '2903881 - PAPEL SULFITE DE PAPELARIA,FORMATO A4,(210X297)MM,75G,BRANCO' ao longo dos meses com uma estimativa gráfica da tendência central e intervalo de confiança.

# %%
df_bec.head(1)
# Out:
#                    Cód Desc Órgão Mês Ano Encerramento  \
# 0  01000 - ASSEMBLEIA LEGISLATIVA           2019-09-01
#
#                                 Cod Desc Fornecedor  \
# 0  28363983000140 - OFICIAL WEB COMERCIAL LTDA - ME
#
#   Descrição Procedimento Compra  \
# 0         DISPENSA DE LICITAÇÃO
#
#                                        Cod Desc Item  Quantidade de Item  \
# 0  4843274 - FILME PROTETIVO, DE POLIESTER, 1,00X...                   1
#
#    Valor Unitário Negociado  Valor Total Negociado em R$  Quantidade Negociada
# 0                     168.3                        673.2                   4.0

# %%
# Implementação Ex4.01
#
df_papel = df_bec[df_bec['Cod Desc Item'] == 
            '2903881 - PAPEL SULFITE DE PAPELARIA,FORMATO A4,(210X297)MM,75G,BRANCO']
# mais este filtro abaixo para remover outliers que distorcem o gráfico
sns.lineplot(x='Mês Ano Encerramento', y='Valor Unitário Negociado',data=df_papel)

# %% [markdown]
# ### Bokeh - Dados em Mapas
#
# Bokeh é uma biblioteca para visualização de dados em Python de forma interativa

# %%
# carregamento da biblioteca
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import WMTSTileSource

# %% [markdown]
# **Exemplo 5.01** - Visualização da localização de roubos em SP

# %%
df_crime = pd.read_excel(path+'05-DS_CRIME_SP.xlsx', parse_dates=['DATA_OCORRENCIA_BO'])
df_crime = df_crime[['RUBRICA', 'NOME_DELEGACIA', 'DATA_OCORRENCIA_BO', 
                     'HORA_OCORRENCIA_BO','DESCR_TIPOLOCAL', 'LOGRADOURO', 
                     'NUMERO_LOGRADOURO','SEXO_PESSOA', 
                     'IDADE_PESSOA','x', 'y']]
df_crime.head(4)
# Out:
#             RUBRICA                  NOME_DELEGACIA DATA_OCORRENCIA_BO  \
# 0  Roubo (art. 157)  40º D.P.  VILA STA MARIA               2015-05-21
# 1  Roubo (art. 157)  75º D.P. JARDIM ARPOADOR               2015-06-24
# 2  Roubo (art. 157)  91º D.P. CEASA                         2015-10-28
# 3  Roubo (art. 157)  DEIC - 3ª DELEGACIA DA DIVECAR         2015-06-11
#
#   HORA_OCORRENCIA_BO                           DESCR_TIPOLOCAL  \
# 0           21:00:00  Via pública
# 1           06:40:00  Via pública
# 2           20:15:00  Via pública
# 3           09:00:00  Via pública
#
#                                  LOGRADOURO  NUMERO_LOGRADOURO SEXO_PESSOA  \
# 0  RUA DOMICIANO RIBEIRO                                 968.0           M
# 1  RUA FREI VITAL DE FRESCAROLO                           30.0           M
# 2  RUA ALIANCA LIBERAL                                   286.0           M
# 3  RUA ANTONIO CRESPO                                     33.0           M
#
#    IDADE_PESSOA             x             y
# 0            54 -5.195591e+05 -2.690467e+06
# 1            16 -5.208704e+06 -2.704744e+06
# 2            56 -5.201337e+06 -2.695291e+06
# 3            31 -5.169712e+06 -2.622279e+05

# %%
# filtro de dados da rubrica 
df_roubo = df_crime.loc[df_crime['RUBRICA'] == 'Roubo (art. 157)', 
                        ['RUBRICA', 'x', 'y']].dropna()
df_roubo.head(2)
# Out:
#             RUBRICA             x             y
# 0  Roubo (art. 157) -5.195591e+05 -2.690467e+06
# 1  Roubo (art. 157) -5.208704e+06 -2.704744e+06

# %%
df_crime['RUBRICA'].value_counts()
# Out:
# Roubo (art. 157)                                                          81766
# Furto (art. 155)                                                          56104
# Lesão corporal (art. 129)                                                 12865
# Furto qualificado (art. 155, §4o.)                                        11989
# Lesão corporal culposa na direção de veículo automotor (Art. 303)         11374
# Lesão corporal (art 129 § 9º)                                              2757
# A.I.-Roubo (art. 157)                                                      2083
# Homicídio simples (art. 121)                                               1365
# A.I.-Lesão corporal (art. 129)                                             1055
# Lesão corporal culposa (art. 129. §6o.)                                     480
# A.I.-Furto (art. 155)                                                       336
# Homicídio culposo na direção de veículo automotor (Art. 302)                286
# Homicídio qualificado (art. 121, §2o.)                                      238
# A.I.-Furto qualificado (art. 155, §4o.)                                     189
# A.I.-Lesão corporal culposa na direção de veículo automotor (Art. 303)      103
# Lesão corporal de natureza GRAVE (art. 129, §1o.)                            66
# A.I.-Homicídio simples (art. 121)                                            36
# A.I.-Lesão corporal (art 129 § 9º)                                           35
# Homicídio culposo (art. 121, §3o.)                                           14
# Furto de coisa comum (art. 156)                                              14
# Lesão corporal seguida de morte (art. 129, §3o.)                             12
# A.I.-Homicídio qualificado (art. 121, §2o.)                                   9
# A.I.-Lesão corporal culposa (art. 129. §6o.)                                  6
# A.I.-Homicídio culposo na direção de veículo automotor (Art. 302)             5
# Lesão corporal  de natureza 'GRAVÍSSIMA' (art. 129, §2o.)                     4
# A.I.-Lesão corporal de natureza GRAVE (art. 129, §1o.)                        1
# Name: RUBRICA, dtype: int64

# %%
# web mercator coordinates
SP = y_range, x_range =  ((-2753408,-2632018), (-5232016, -5120696))
p = figure(x_range=x_range, y_range=y_range, x_axis_type="mercator", 
           y_axis_type="mercator")
url = 'http://a.basemaps.cartocdn.com/rastertiles/voyager/{Z}/{X}/{Y}.png'
attribution = "Tiles by Carto, under CC BY 3.0. Data by OSM, under ODbL"
p.add_tile(WMTSTileSource(url=url, attribution=attribution))
p.circle(x=df_roubo['x'], y=df_roubo['y'], fill_color='orange', size=5)
output_notebook()
show(p)
# Out:
#   <div class="bk-root" id="a6ed332c-49cd-42b7-b8fc-b01f7c49968b" data-root-id="1002"></div>

# %% [markdown]
# #### Exercício 5.01
#
# Exibir no mapa as ocorrências da RUBRICA 'Homicídio simples (art. 121)'

# %%
# Implementação 5.01
#
#
df_homicidio = df_crime.loc[df_crime['RUBRICA'] == 'Homicídio simples (art. 121)', 
                        ['RUBRICA', 'x', 'y']].dropna()
df_homicidio.head(2)
# Out:
#                              RUBRICA             x             y
# 109324  Homicídio simples (art. 121) -5.171506e+05 -2.706415e+06
# 109325  Homicídio simples (art. 121) -5.173951e+06 -2.704656e+06

# %%
# web mercator coordinates
SP = y_range, x_range =  ((-2753408,-2632018), (-5232016, -5120696))
p = figure(x_range=x_range, y_range=y_range, x_axis_type="mercator", 
           y_axis_type="mercator")
url = 'http://a.basemaps.cartocdn.com/rastertiles/voyager/{Z}/{X}/{Y}.png'
attribution = "Tiles by Carto, under CC BY 3.0. Data by OSM, under ODbL"
p.add_tile(WMTSTileSource(url=url, attribution=attribution))
p.circle(x=df_homicidio['x'], y=df_homicidio['y'], fill_color='blue', size=5)
output_notebook()
show(p)
# Out:
#   <div class="bk-root" id="fa6a53ae-a436-4668-bb2c-42c5ee6ab71b" data-root-id="1115"></div>
